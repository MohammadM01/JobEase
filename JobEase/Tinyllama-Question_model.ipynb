# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/models/fine_tuned_tinyllama_cpu_v2.zip" -d /content/
# Out:
# Archive:  /content/drive/MyDrive/models/fine_tuned_tinyllama_cpu_v2.zip
#    creating: /content/fine_tuned_tinyllama_cpu_v2/
#   inflating: /content/fine_tuned_tinyllama_cpu_v2/adapter_config.json
#   inflating: /content/fine_tuned_tinyllama_cpu_v2/adapter_model.safetensors
#   inflating: /content/fine_tuned_tinyllama_cpu_v2/chat_template.jinja
#   inflating: /content/fine_tuned_tinyllama_cpu_v2/README.md
#   inflating: /content/fine_tuned_tinyllama_cpu_v2/special_tokens_map.json
#   inflating: /content/fine_tuned_tinyllama_cpu_v2/tokenizer.json
#   inflating: /content/fine_tuned_tinyllama_cpu_v2/tokenizer_config.json
#   inflating: /content/fine_tuned_tinyllama_cpu_v2/training_args.bin

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_path = "/content/fine_tuned_tinyllama_cpu_v2"

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path)

# (Optional) move to CPU explicitly — Colab does this by default if no GPU is used
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print("✅ Model loaded successfully on", device)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# ✅ Model loaded successfully on cuda

# %%
prompt = """Interview Type: HR
Skills: Communication, Teamwork
Question: Tell me about yourself.
"""
inputs = tokenizer(prompt, return_tensors="pt").to(device)
outputs = model.generate(**inputs, max_new_tokens=100)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Interview Type: HR
# Skills: Communication, Teamwork
# Question: Tell me about yourself.
# Answer: I'm a software engineer with a focus on performance and scalability. I'm passionate about building scalable systems and optimizing performance.
# Follow-up: Can you provide an example of a challenging project or problem you've faced and how you resolved it?<|endoftext|>
# <Interviewee: Jake: Hiring a software engineer for a startup, preferably in a technical role like frontend or backend.>
# <

# %%
prompt = """Interview Type: HR
Skills: Communication, Teamwork
Question: Can you provide an example of a challenging project or problem you've faced and how you resolved it?
"""
inputs = tokenizer(prompt, return_tensors="pt").to(device)
outputs = model.generate(**inputs, max_new_tokens=100)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Interview Type: HR
# Skills: Communication, Teamwork
# Question: Can you provide an example of a challenging project or problem you've faced and how you resolved it?
# Answer: Describe the situation, what you did, and how you resolved the issue.
# Follow-up: What were the consequences of failing to resolve this issue and how would you have handled it?<|endoftext|>
# Based on the text: Interview question: Describe a challenging project or problem you've faced and how you resolved it.
# Follow-up: What were the consequences of failing to resolve this issue and how would you have handled

# %%
prompt = """Interview Type: HR
Skills: Communication, Teamwork
Question: Tell me about yourself and about your projects.
"""
inputs = tokenizer(prompt, return_tensors="pt").to(device)
outputs = model.generate(**inputs, max_new_tokens=100)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3295125008.py in <cell line: 0>()
#       3 Question: Tell me about yourself and about your projects.
#       4 """
# ----> 5 inputs = tokenizer(prompt, return_tensors="pt").to(device)
#       6 outputs = model.generate(**inputs, max_new_tokens=100)
#       7 print(tokenizer.decode(outputs[0], skip_special_tokens=True))
#
# NameError: name 'tokenizer' is not defined
